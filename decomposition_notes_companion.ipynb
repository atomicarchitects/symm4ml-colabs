# %% [markdown]
# # Decomposition and Products — Notes Companion
#
# **6.7970/8.750 Symmetry and its Application to Machine Learning**
#
# This notebook accompanies the [Decomposition and Products notes](https://symm4ml.mit.edu/notes/decomposition-and-products). Run these examples to decompose representations into irreps and explore tensor products.
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/atomicarchitects/symm4ml-colabs/blob/main/decomposition_notes_companion.ipynb)

# %% [markdown]
# ## Setup

# %%
# %%capture
# !pip install https://symm4ml.mit.edu/_static/symm4ml_s26/symm4ml/symm4ml_latest.zip

# %%
import numpy as np
from symm4ml import groups, linalg, rep
from symm4ml.utils import match_character_tables, print_character_table

# %% [markdown]
# ## Reference: $P(3)$ data

# %%
# Build P(3) table and find all irreps
p3_matrices = groups.permutation_matrices(3)
table = groups.make_multiplication_table(p3_matrices)
irreps = rep.infer_irreps(table)

print(f"P(3): h = {len(table)}, {len(irreps)} irreps, dimensions: {[ir.shape[1] for ir in irreps]}")

# %% [markdown]
# ---
# ## Decomposing the Regular Representation
#
# The **regular representation** of $P(3)$ is $6 \times 6$ and contains every irrep: 1 copy of $\Gamma_1$, 1 copy of $\Gamma_1'$, and **2 copies** of $\Gamma_2$. Let's walk through the decomposition algorithm step by step — the same example shown in the [interactive graphic](https://symm4ml.mit.edu/notes/decomposition-and-products).
#
# We use the same multiplication table as the graphic, with elements E, A, B, C (reflections), D, F (rotations).

# %%
# P(3) multiplication table (same element ordering as the interactive graphic)
elem_names = ['E', 'A', 'B', 'C', 'D', 'F']  # A,B,C = reflections; D,F = rotations
graphic_table = np.array([
    [0, 1, 2, 3, 4, 5],
    [1, 0, 5, 4, 3, 2],
    [2, 4, 0, 5, 1, 3],
    [3, 5, 4, 0, 2, 1],
    [4, 2, 3, 1, 5, 0],
    [5, 3, 1, 2, 0, 4],
])

# Step 1: Build the regular representation
reg = rep.regular_representation(graphic_table)
print(f"Step 1 — D_reg: {reg.shape}  (6 elements × 6×6 matrices)")
print(f"  Contains: 1×Γ₁ + 1×Γ₁' + 2×Γ₂ → dim = 1+1+2×2 = 6 ✓")

# Step 2: Find the commutant
Q = linalg.infer_change_of_basis(reg, reg)
print(f"\nStep 2 — Commutant: {len(Q)} basis matrices (= Σ aⱼ² = 1²+1²+2² = 6)")

# %%
# Step 3: Form M = Σ αᵢ Qᵢ with random weights (seed 3, matching the graphic)
np.random.seed(3)
weights = np.random.random(len(Q))
M = np.einsum("n,nij->ij", weights, Q)

eigenvalues = sorted(np.linalg.eigvals(M).real)
print(f"Step 3 — Random M eigenvalues: {np.round(eigenvalues, 2)}")
print(f"  → 4 distinct values → 4 invariant subspaces (dim 2, 2, 1, 1)")

# %% [markdown]
# Each eigenspace is an invariant subspace. Project $D_\text{reg}$ onto each one to recover the irreps.

# %%
# Step 4: Project D_reg onto each eigenspace → recover irreps
np.random.seed(3)
recovered = rep.decompose_rep_into_irreps(reg)

print(f"Step 4 — Recovered {len(recovered)} irreps from D_reg:")
for i, sub in enumerate(recovered):
    d = sub.shape[1]
    all_pos = all(np.trace(sub[g]).real > 0.5 for g in range(len(sub)))
    label = "A₁ (trivial)" if d == 1 and all_pos else "A₂ (sign)" if d == 1 else "E (standard)"
    print(f"  {d}×{d}  →  {label}")

# %%
# Why random weights? Uniform weights give degenerate eigenvalues:
M_uniform = np.einsum("n,nij->ij", np.ones(len(Q)), Q)
print(f"Uniform weights eigenvalues: {np.round(sorted(np.linalg.eigvals(M_uniform).real), 2)}")
print("→ Only 1 nonzero eigenvalue — can't separate irreps!")

# %% [markdown]
# ---
# ## Example: Decomposing a Scrambled Representation
#
# The algorithm works even when block structure is **hidden** by a random change of basis.

# %%
# Build Γ₁ ⊕ Γ₂, scramble with a random unitary, then decompose
gamma_1d = [ir for ir in irreps if ir.shape[1] == 1][0]
gamma_2d = [ir for ir in irreps if ir.shape[1] == 2][0]
direct = rep.direct_sum(gamma_1d, gamma_2d)

np.random.seed(123)
U, _ = np.linalg.qr(np.random.randn(3, 3))
scrambled = rep.similarity_transform(direct, U)
print(f"Scrambled D(g=1) — no visible blocks:\n{np.round(scrambled[1], 4)}")

recovered = rep.decompose_rep_into_irreps(scrambled)
print(f"\nRecovered {len(recovered)} irreps: dims = {[s.shape[1] for s in recovered]}")
print("The algorithm sees through the scrambling!")

# %% [markdown]
# ---
# ## Tensor Products from Characters
#
# Since $\text{tr}(A \otimes B) = \text{tr}(A) \cdot \text{tr}(B)$, we can decompose tensor products using only the **character table**:
#
# $$a_k = \frac{1}{h} \sum_C N_C \, [\chi^{(\Gamma_k)}(C)]^* \, \chi^{(\Gamma_i)}(C) \, \chi^{(\Gamma_j)}(C)$$
#
# See the [Characters notebook](https://colab.research.google.com/github/atomicarchitects/symm4ml-colabs/blob/main/characters_notes_companion.ipynb) for the derivation of this decomposition formula.

# %%
# Character table (Dresselhaus convention, same as Characters notebook)
conj_classes = groups.conjugacy_classes(table)
ref_chars = np.array([[1,1,1], [1,1,-1], [2,-1,0]])
char_table_raw = rep.character_table(irreps, conj_classes)
row_perm, col_perm = match_character_tables(char_table_raw, ref_chars)

irreps_ordered = [irreps[i] for i in row_perm]
conj_classes_list = [list(conj_classes)[j] for j in col_perm]
char_table = rep.character_table(irreps_ordered, conj_classes_list)
class_sizes = np.array([len(c) for c in conj_classes_list])
h, names = len(table), ['A₁', 'A₂', 'E']

print_character_table(char_table, names, ['E', '2C₃', '3σ'], title="P(3) character table")

# Full tensor product table from characters
print("\nTensor product table (from characters):\n")
print(f"{'⊗':>6s}  " + "  ".join(f"{n:>10s}" for n in names))
print(f"{'':>6s}  " + "-" * 36)
for i in range(len(names)):
    row = f"{names[i]:>6s}  "
    for j in range(len(names)):
        chi_prod = char_table[i] * char_table[j]
        parts = []
        for k in range(len(names)):
            a_k = int(np.round(np.sum(class_sizes * np.conj(char_table[k]) * chi_prod).real / h))
            parts.extend([names[k]] * a_k)
        row += f"{'⊕'.join(parts):>12s}"
    print(row)

# %% [markdown]
# We can also decompose tensor products directly from the representation matrices using `rep.tensor_product` and `rep.decompose_rep_into_irreps`:

# %%
# Matrix-based tensor product decomposition
# E ⊗ E → build the 4D representation, then decompose into irreps
tp = rep.tensor_product(irreps_ordered[2], irreps_ordered[2])  # E ⊗ E
sub = rep.decompose_rep_into_irreps(tp)

print(f"E ⊗ E: {tp.shape[1]}D rep → decomposes into {len(sub)} irreps:")
for s in sub:
    d = s.shape[1]
    all_pos = all(np.trace(s[g]).real > 0.5 for g in range(len(s)))
    label = "A₁" if d == 1 and all_pos else "A₂" if d == 1 else "E"
    print(f"  {d}×{d}  →  {label}")
print(f"\n→ E ⊗ E = A₁ ⊕ A₂ ⊕ E  (matches the character table!)")
